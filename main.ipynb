# %% [markdown]
# # SyaTTS tiny from-scratch Colab
#
# Run top to bottom. This trains a tiny baseline on LJSpeech and saves checkpoints to Drive.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
PROJECT_DIR = "/content/drive/MyDrive/SyaTTS"
# %cd $PROJECT_DIR
# !test -f requirements.txt || (echo "Missing project files. Upload/copy the whole SyaTTS folder to MyDrive/SyaTTS, not just main.ipynb." && ls -la && false)
# !pip install -q -r requirements.txt
# Out:
# [Errno 2] No such file or directory: '/content/drive/MyDrive/SyaTTS'
# /content
# ERROR: Could not open requirements file: [Errno 2] No such file or directory: 'requirements.txt'

# %%
# !python scripts/download_ljspeech.py

# %%
# !python scripts/smoke_test.py

# %%
# !python scripts/train.py --data data/LJSpeech-1.1 --out /content/drive/MyDrive/SyaTTS/runs/syatts-tiny --limit 1000

# %%
# !python scripts/infer.py --ckpt /content/drive/MyDrive/SyaTTS/runs/syatts-tiny/latest.pt --text "hello from syatts" --out /content/drive/MyDrive/SyaTTS/sample.wav
